# %%
from sklearn.datasets import fetch_openml
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# import
mnist = fetch_openml('MNIST original')
X, y = mnist["data"], mnist["target"]

# scale
X = X / 255

# one-hot encode labels
digits = 10
examples = y.shape[0]
y = y.reshape(1, examples)
Y_new = np.eye(digits)[y.astype('int32')]
Y_new = Y_new.T.reshape(digits, examples)

# split, reshape, shuffle
m = 60000
m_test = X.shape[0] - m
X_train, X_test = X[:m].T, X[m:].T
Y_train, Y_test = Y_new[:,:m], Y_new[:,m:]
shuffle_index = np.random.permutation(m)
X_train, Y_train = X_train[:, shuffle_index], Y_train[:, shuffle_index]
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:52, in _retry_with_clean_cache.<locals>.decorator.<locals>.wrapper(*args, **kw)
#      51 try:
# ---> 52     return f(*args, **kw)
#      53 except URLError:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:224, in _get_json_content_from_openml_api.<locals>._load_json()
#     221 @_retry_with_clean_cache(url, data_home)
#     222 def _load_json():
#     223     with closing(
# --> 224         _open_openml_url(url, data_home, n_retries=n_retries, delay=delay)
#     225     ) as response:
#     226         return json.loads(response.read().decode("utf-8"))
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:156, in _open_openml_url(openml_path, data_home, n_retries, delay)
#     154 with TemporaryDirectory(dir=dir_name) as tmpdir:
#     155     with closing(
# --> 156         _retry_on_network_error(n_retries, delay, req.full_url)(urlopen)(
#     157             req, timeout=delay
#     158         )
#     159     ) as fsrc:
#     160         opener: Callable
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:84, in _retry_on_network_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      83 try:
# ---> 84     return f(*args, **kwargs)
#      85 except (URLError, TimeoutError) as e:
#      86     # 412 is a specific OpenML error code.
#
# File /usr/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#
# File /usr/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#
# File /usr/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     501 func = getattr(handler, meth_name)
# --> 502 result = func(*args)
#     503 if result is not None:
#
# File /usr/lib/python3.8/urllib/request.py:1397, in HTTPSHandler.https_open(self, req)
#    1396 def https_open(self, req):
# -> 1397     return self.do_open(http.client.HTTPSConnection, req,
#    1398         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/lib/python3.8/urllib/request.py:1354, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1353 try:
# -> 1354     h.request(req.get_method(), req.selector, req.data, headers,
#    1355               encode_chunked=req.has_header('Transfer-encoding'))
#    1356 except OSError as err: # timeout error
#
# File /usr/lib/python3.8/http/client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1255 """Send a complete request to the server."""
# -> 1256 self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.8/http/client.py:1267, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1265     skips['skip_accept_encoding'] = 1
# -> 1267 self.putrequest(method, url, **skips)
#    1269 # chunked encoding will happen if HTTP/1.1 is used and either
#    1270 # the caller passes encode_chunked=True or the following
#    1271 # conditions hold:
#    1272 # 1. content-length has not been explicitly set
#    1273 # 2. the body is a file or iterable, but not a str or bytes-like
#    1274 # 3. Transfer-Encoding has NOT been explicitly set by the caller
#
# File /usr/lib/python3.8/http/client.py:1101, in HTTPConnection.putrequest(self, method, url, skip_host, skip_accept_encoding)
#    1100 url = url or '/'
# -> 1101 self._validate_path(url)
#    1103 request = '%s %s %s' % (method, url, self._http_vsn_str)
#
# File /usr/lib/python3.8/http/client.py:1201, in HTTPConnection._validate_path(self, url)
#    1200 if match:
# -> 1201     raise InvalidURL(f"URL can't contain control characters. {url!r} "
#    1202                      f"(found at least {match.group()!r})")
#
# InvalidURL: URL can't contain control characters. '/api/v1/json/data/list/data_name/mnist original/limit/2/status/active/' (found at least ' ')
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# Input In [23], in <cell line: 6>()
#       3 import numpy as np
#       5 # import
# ----> 6 mnist = fetch_openml('MNIST original')
#       7 X, y = mnist["data"], mnist["target"]
#       9 # scale
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:746, in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y, as_frame, n_retries, delay)
#     740     if data_id is not None:
#     741         raise ValueError(
#     742             "Dataset data_id={} and name={} passed, but you can only "
#     743             "specify a numeric data_id or a name, not "
#     744             "both.".format(data_id, name)
#     745         )
# --> 746     data_info = _get_data_info_by_name(
#     747         name, version, data_home, n_retries=n_retries, delay=delay
#     748     )
#     749     data_id = data_info["did"]
#     750 elif data_id is not None:
#     751     # from the previous if statement, it is given that name is None
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:285, in _get_data_info_by_name(name, version, data_home, n_retries, delay)
#     283 url = _SEARCH_NAME.format(name) + "/status/active/"
#     284 error_msg = "No active dataset {} found.".format(name)
# --> 285 json_data = _get_json_content_from_openml_api(
#     286     url,
#     287     error_msg,
#     288     data_home=data_home,
#     289     n_retries=n_retries,
#     290     delay=delay,
#     291 )
#     292 res = json_data["data"]["dataset"]
#     293 if len(res) > 1:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:229, in _get_json_content_from_openml_api(url, error_message, data_home, n_retries, delay)
#     226         return json.loads(response.read().decode("utf-8"))
#     228 try:
# --> 229     return _load_json()
#     230 except HTTPError as error:
#     231     # 412 is an OpenML specific error code, indicating a generic error
#     232     # (e.g., data not found)
#     233     if error.code != 412:
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:60, in _retry_with_clean_cache.<locals>.decorator.<locals>.wrapper(*args, **kw)
#      58 if os.path.exists(local_path):
#      59     os.unlink(local_path)
# ---> 60 return f(*args, **kw)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:224, in _get_json_content_from_openml_api.<locals>._load_json()
#     221 @_retry_with_clean_cache(url, data_home)
#     222 def _load_json():
#     223     with closing(
# --> 224         _open_openml_url(url, data_home, n_retries=n_retries, delay=delay)
#     225     ) as response:
#     226         return json.loads(response.read().decode("utf-8"))
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:156, in _open_openml_url(openml_path, data_home, n_retries, delay)
#     149 try:
#     150     # Create a tmpdir as a subfolder of dir_name where the final file will
#     151     # be moved to if the download is successful. This guarantees that the
#     152     # renaming operation to the final location is atomic to ensure the
#     153     # concurrence safety of the dataset caching mechanism.
#     154     with TemporaryDirectory(dir=dir_name) as tmpdir:
#     155         with closing(
# --> 156             _retry_on_network_error(n_retries, delay, req.full_url)(urlopen)(
#     157                 req, timeout=delay
#     158             )
#     159         ) as fsrc:
#     160             opener: Callable
#     161             if is_gzip_encoded(fsrc):
#
# File ~/.local/lib/python3.8/site-packages/sklearn/datasets/_openml.py:84, in _retry_on_network_error.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      82 while True:
#      83     try:
# ---> 84         return f(*args, **kwargs)
#      85     except (URLError, TimeoutError) as e:
#      86         # 412 is a specific OpenML error code.
#      87         if isinstance(e, HTTPError) and e.code == 412:
#
# File /usr/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File /usr/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File /usr/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File /usr/lib/python3.8/urllib/request.py:1397, in HTTPSHandler.https_open(self, req)
#    1396 def https_open(self, req):
# -> 1397     return self.do_open(http.client.HTTPSConnection, req,
#    1398         context=self._context, check_hostname=self._check_hostname)
#
# File /usr/lib/python3.8/urllib/request.py:1354, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1352 try:
#    1353     try:
# -> 1354         h.request(req.get_method(), req.selector, req.data, headers,
#    1355                   encode_chunked=req.has_header('Transfer-encoding'))
#    1356     except OSError as err: # timeout error
#    1357         raise URLError(err)
#
# File /usr/lib/python3.8/http/client.py:1256, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1253 def request(self, method, url, body=None, headers={}, *,
#    1254             encode_chunked=False):
#    1255     """Send a complete request to the server."""
# -> 1256     self._send_request(method, url, body, headers, encode_chunked)
#
# File /usr/lib/python3.8/http/client.py:1267, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1264 if 'accept-encoding' in header_names:
#    1265     skips['skip_accept_encoding'] = 1
# -> 1267 self.putrequest(method, url, **skips)
#    1269 # chunked encoding will happen if HTTP/1.1 is used and either
#    1270 # the caller passes encode_chunked=True or the following
#    1271 # conditions hold:
#    1272 # 1. content-length has not been explicitly set
#    1273 # 2. the body is a file or iterable, but not a str or bytes-like
#    1274 # 3. Transfer-Encoding has NOT been explicitly set by the caller
#    1276 if 'content-length' not in header_names:
#    1277     # only chunk body if not explicitly set for backwards
#    1278     # compatibility, assuming the client code is already handling the
#    1279     # chunking
#
# File /usr/lib/python3.8/http/client.py:1101, in HTTPConnection.putrequest(self, method, url, skip_host, skip_accept_encoding)
#    1098 self._method = method
#    1100 url = url or '/'
# -> 1101 self._validate_path(url)
#    1103 request = '%s %s %s' % (method, url, self._http_vsn_str)
#    1105 self._output(self._encode_request(request))
#
# File /usr/lib/python3.8/http/client.py:1201, in HTTPConnection._validate_path(self, url)
#    1199 match = _contains_disallowed_url_pchar_re.search(url)
#    1200 if match:
# -> 1201     raise InvalidURL(f"URL can't contain control characters. {url!r} "
#    1202                      f"(found at least {match.group()!r})")
#
# InvalidURL: URL can't contain control characters. '/api/v1/json/data/list/data_name/mnist original/limit/2/status/active/' (found at least ' ')

# %%
def sigmoid(x):
    return(1/(1 + np.exp(-x)))
